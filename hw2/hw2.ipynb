# %% [markdown]
# # Домашнее задание:
# - Создать базу
# - Заполнить её данными: одна или несколько таблиц
# - Выполнить ANALYZE
# - Придумать SQL запрос(ы) к базе
# - Замерить их производительность
# - Отключить автоматическое переанализироание
# - Поменять содержимое базы, желательно не меняя её объем, но меняя распределение
# - Повторно произвести замеры: должно стать медленнее
#
# При этом подобрать запросы и данные так, что бы разница по скорости была ощутима. Желательно в десятки процентов или даже в 2 раза
#
# ## Результаты
# Приложил файлы для создания и заполнения базы, приенил ANLYZE
#
# ### Запросы
# - Сумма продаж по месяцам
# ![Сумма продаж по месяцам](images/Сумма_продаж_по_месяцам.jpg)
# - Топ-10 покупателей с наибольшими суммами покупок
# ![Топ-10 покупателей с наибольшими суммами покупок](images/Топ-10_покупателей_с_наибольшими_суммами_покупок.jpg)
# - Распределение количества покупок по категориям скидок
# ![Распределение количества покупок по категориям скидок](images/Распределение_количества_покупок_по_категориям_скидок.jpg)
#
# ### Отключение автоматического переанализироания и замена содержимого базы
# ![Отключение автоматического переанализироания и замена содержимого базы](images/отключение_автоматического_переанализирования_и_изменение_данных.jpg)
#
# ## Новые замеры
# - Сумма продаж по месяцам
# ![Сумма продаж по месяцам](images/Сумма_продаж_по_месяцам_после.jpg)
# - Топ-10 покупателей с наибольшими суммами покупок
# ![Топ-10 покупателей с наибольшими суммами покупок](images/Топ-10_покупателей_с_наибольшими_суммами_покупок_после.jpg)
# - Распределение количества покупок по категориям скидок
# ![Распределение количества покупок по категориям скидок](images/Распределение_количества_покупок_по_категориям_скидок_после.jpg)
#
# ## Как можно видеть, время и правда сильно просело
